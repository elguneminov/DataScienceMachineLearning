# %% [markdown]
# # Plotly and Cufflinks

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.randn(100,4), columns = 'A B C D'.split())

# %%
df1.head()
# Out:
#           A         B         C         D
# 0 -0.654476 -0.753492 -1.823303 -0.694968
# 1 -0.339811 -0.438076 -1.118837  0.822415
# 2  0.951334 -1.738295 -0.590546  0.965182
# 3 -0.620135 -0.631186 -1.296961  0.055372
# 4 -0.536456 -1.000726 -0.664263 -0.594890

# %%
df2 = pd.DataFrame({'Category': ['A', 'B', 'C'], 'Values': [34, 56, 78]})

# %%
df2
# Out:
#   Category  Values
# 0        A      34
# 1        B      56
# 2        C      78

# %%
# Plolty and Cufflinks

# %% [markdown]
# - scatter
# - bar
# - box
# - spread
# - ratio
# - heatmap
# - surface
# - histogram
# - bubble

# %%
df1.iplot(kind = 'scatter', x = 'A', y = 'B', mode = 'markers')
# Out:
# <div>
#
#
#             <div id="6497f446-f14f-4c3b-bab5-ef5cf01a9453" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6497f446-f14f-4c3b-bab5-ef5cf01a9453")) {
#                     Plotly.newPlot(
#                         '6497f446-f14f-4c3b-bab5-ef5cf01a9453',
# ...

# %%
df2.iplot(kind = 'bar', x = 'Category', y = 'Values')
# Out:
# <div>
#
#
#             <div id="5c01d213-939a-414d-9831-8ea3a9aa9eac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c01d213-939a-414d-9831-8ea3a9aa9eac")) {
#                     Plotly.newPlot(
#                         '5c01d213-939a-414d-9831-8ea3a9aa9eac',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [34, 56, 78]}],
# ...

# %%
df1.count().iplot(kind = 'bar')
# Out:
# <div>
#
#
#             <div id="365ce84b-870e-47d9-9c56-0c15884f82a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("365ce84b-870e-47d9-9c56-0c15884f82a9")) {
#                     Plotly.newPlot(
#                         '365ce84b-870e-47d9-9c56-0c15884f82a9',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df1.iplot(kind = 'box')
# Out:
# <div>
#
#
#             <div id="1247e147-1ccd-4e83-87a6-0bc845230638" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1247e147-1ccd-4e83-87a6-0bc845230638")) {
#                     Plotly.newPlot(
#                         '1247e147-1ccd-4e83-87a6-0bc845230638',
# ...

# %%
df = pd.DataFrame({'X': [1,2,3,4,5], 'Y': [10, 20, 30, 40, 50], 'Z': [5,4,3,2,1]})

# %%
df
# Out:
#    X   Y  Z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  40  2
# 4  5  50  1

# %%
df.iplot(kind = 'surface', colorscale= 'rdylbu')
# Out:
# <div>
#
#
#             <div id="d6f09877-fee3-4cba-8b6b-578d3b948b77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d6f09877-fee3-4cba-8b6b-578d3b948b77")) {
#                     Plotly.newPlot(
#                         'd6f09877-fee3-4cba-8b6b-578d3b948b77',
# ...

# %%
df1 [['A', 'B']].iplot(kind = 'spread')
# Out:
# <div>
#
#
#             <div id="d1507aa5-f1c4-47f8-9878-780397a55bf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d1507aa5-f1c4-47f8-9878-780397a55bf4")) {
#                     Plotly.newPlot(
#                         'd1507aa5-f1c4-47f8-9878-780397a55bf4',
# ...

# %%
df1['A'].iplot(kind = 'hist', bins = 30)
# Out:
# <div>
#
#
#             <div id="b338e1b5-7761-406e-b61f-7d3f10600a61" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b338e1b5-7761-406e-b61f-7d3f10600a61")) {
#                     Plotly.newPlot(
#                         'b338e1b5-7761-406e-b61f-7d3f10600a61',
# ...

# %%
df1.iplot(kind = 'bubble', x = 'A', y = 'B', size = 'C')
# Out:
# <div>
#
#
#             <div id="952f3146-b699-4477-aecf-f66eb7e206ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("952f3146-b699-4477-aecf-f66eb7e206ab")) {
#                     Plotly.newPlot(
#                         '952f3146-b699-4477-aecf-f66eb7e206ab',
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="ee3c2920-b223-4192-a949-8d9806036d50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee3c2920-b223-4192-a949-8d9806036d50")) {
#                     Plotly.newPlot(
#                         'ee3c2920-b223-4192-a949-8d9806036d50',
# ...
